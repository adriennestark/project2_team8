# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from newsapi import NewsApiClient
analyzer = SentimentIntensityAnalyzer()
load_dotenv()
# %matplotlib inline

# %%
# Reading your api key environment variable
api_key = "1bdbdab472c048398a14e434cde39dbb"

# %%
# Creating a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetching the L brands news articles
lb_headlines = newsapi.get_everything(q="JC Penney AND covid",
                                      language="en",
                                      sort_by="relevancy")

# %%
# Print total number of articles l brands
print(f"Total articles about L Brands and Covid: {lb_headlines['totalResults']}")
# Out:
# Total articles about L Brands and Covid: 16

# %%
# Fetching the Carnival news articles
ccl_headlines = newsapi.get_everything(q="carnival cruise AND covid", language="en")

# %%
# Print total number of articles CCL
print(f"Total articles about Carnival and Covid: {ccl_headlines['totalResults']}")
# Out:
# Total articles about Carnival and Covid: 280

# %%
# Fetching the delta news articles
dal_headlines = newsapi.get_everything(q="delta and covid", language="en")

# %%
# Fetching the ETSY news articles
etsy_headlines = newsapi.get_everything(q="ETSY and covid", language="en")

# %%
# Fetching the S&P500 news articles
sp500_headlines = newsapi.get_everything(q="s&p500 stock index and covid", language="en")

# %%
# Creating the lb sentiment scores DataFrame
lb_sentiments = []

for article in lb_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        lb_sentiments.append({
            "text": text,
            "date": date,
            "Compound": compound,
            "Positive": pos,
            "Negative": neg,
            "Neutral": neu})
        
    except AttributeError:
        pass
    
# Creating a DataFrame
lb_df = pd.DataFrame(lb_sentiments)
# Reordering DataFrame columns
cols = ["Compound", "Negative", "Neutral", "Positive", "text"]
lb_df = lb_df[cols]
lb_df
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.0000     0.000    1.000     0.000
# 1    0.1779     0.144    0.654     0.203
# 2    0.9186     0.000    0.690     0.310
# 3   -0.3400     0.066    0.934     0.000
# 4    0.9538     0.000    0.634     0.366
# 5   -0.5267     0.134    0.866     0.000
# 6    0.9260     0.000    0.682     0.318
# 7    0.9260     0.000    0.682     0.318
#
#                                                 text
# 0  COLUMBUS, Ohio, Jan. 07, 2021 (GLOBE NEWSWIRE)...
# 1  For retailers that survived the catastrophe th...
# 2  An ENZOO automatic vacuum food saver machine a...
# 3  Victoria's Secret Angel Taylor Hill took part ...
# 4  Watch Dogs: Legion and an Ulta Beauty sale lea...
# 5  From podcast:  https://bengreenfieldfitness.co...
# 6  Assassins Creed Valhalla and Mpow Flame wirele...
# 7  A 1080p webcamand a sale on Belei skincare pro...

# %%
# Creating the carnival sentiment scores DataFrame
ccl_sentiments = []

for article in ccl_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ccl_sentiments.append({
            "text": text,
            "date": date,
            "Compound": compound,
            "Positive": pos,
            "Negative": neg,
            "Neutral": neu})
        
    except AttributeError:
        pass
    
# Creating a DataFrame
ccl_df = pd.DataFrame(ccl_sentiments)
# Reordering DataFrame columns
cols = ["Compound", "Negative", "Neutral", "Positive", "text"]
ccl_df = ccl_df[cols]
ccl_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.0000     0.000    1.000     0.000
# 1   -0.3182     0.067    0.933     0.000
# 2   -0.3182     0.065    0.935     0.000
# 3   -0.0772     0.098    0.784     0.118
# 4   -0.8225     0.227    0.740     0.033
#
#                                                 text
# 0  By Tim McDonaldBusiness reporter, BBC News\r\n...
# 1  By Reuters Staff\r\nJan 11 (Reuters) - Carniva...
# 2  By Reuters Staff\r\n(Adds detail on cash burn ...
# 3  Bad news for any eager cruisegoers: cruise lin...
# 4  The coronavirus pandemic crisis shows no signs...

# %%
# Creating the delta sentiment scores DataFrame
dal_sentiments = []

for article in dal_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        dal_sentiments.append({
            "text": text,
            "date": date,
            "Compound": compound,
            "Positive": pos,
            "Negative": neg,
            "Neutral": neu})
        
    except AttributeError:
        pass
    
# Creating a DataFrame
dal_df = pd.DataFrame(dal_sentiments)
# Reordering DataFrame columns
cols = ["Compound", "Negative", "Neutral", "Positive", "text"]
dal_df = dal_df[cols]
dal_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.5719     0.090    0.706     0.204
# 1    0.5719     0.088    0.713     0.200
# 2   -0.1531     0.048    0.952     0.000
# 3    0.3182     0.053    0.859     0.089
# 4    0.0000     0.000    1.000     0.000
#
#                                                 text
# 0  CHICAGO (Reuters) - United Airlines and Delta ...
# 1  CHICAGO (Reuters) -United Airlines and Delta A...
# 2  An airplane takes off from the Ronald Reagan N...
# 3  Vulnerable seniors and those who care for them...
# 4  By Reuters Staff\r\nFILE PHOTO: Delta Air Line...

# %%
# Creating the ESTY sentiment scores DataFrame
esty_sentiments = []

for article in esty_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        esty_sentiments.append({
            "text": text,
            "date": date,
            "Compound": compound,
            "Positive": pos,
            "Negative": neg,
            "Neutral": neu})
        
    except AttributeError:
        pass
    
# Creating a DataFrame
esty_df = pd.DataFrame(esty_sentiments)
# Reordering DataFrame columns
cols = ["Compound", "Negative", "Neutral", "Positive", "text"]
esty_df = esty_df[cols]
esty_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.0000       0.0    1.000     0.000
# 1    0.7579       0.0    0.812     0.188
# 2    0.6249       0.0    0.855     0.145
#
#                                                 text
# 0  Cheryl Camarato and Susan Wybiral have owned t...
# 1  Here are five destinations perfect for all lev...
# 2  The New York theater industry supports more th...

# %%
# Creating the SP500 sentiment scores DataFrame
sp500_sentiments = []

for article in sp500_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        sp500_sentiments.append({
            "text": text,
            "date": date,
            "Compound": compound,
            "Positive": pos,
            "Negative": neg,
            "Neutral": neu})
        
    except AttributeError:
        pass
    
# Creating a DataFrame
sp500_df = pd.DataFrame(sp500_sentiments)
# Reordering DataFrame columns
cols = ["Compound", "Negative", "Neutral", "Positive", "text"]
sp500_df = sp500_df[cols]
sp500_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.2584     0.000    0.938     0.062
# 1    0.5908     0.000    0.853     0.147
# 2    0.0000     0.000    1.000     0.000
# 3    0.0000     0.000    1.000     0.000
# 4   -0.5423     0.091    0.909     0.000
#
#                                                 text
# 0  By Reuters Staff\r\nLONDON, Jan 7 (Reuters) - ...
# 1  LONDON (Reuters) - Rioters storming the U.S. C...
# 2  BRAZIL - 2020/11/18: In this photo illustratio...
# 3  GLóRIA DE DOURADOS, BRAZIL - 2020/06/02: In th...
# 4  The year 2020 was off to a bad start as the co...

# %%
# Describing the lb Sentiment
# Compound Scoring:
    # >= 0.05 postive sentiment
    # between -0.05 and 0.05 neutral sentiment
    # <= -0.05 negative sentiment
lb_df.describe()
# Out:
#         Compound   Negative    Neutral   Positive
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.006065   0.053150   0.893450   0.053350
# std     0.399048   0.051651   0.091699   0.081514
# min    -0.440400   0.000000   0.722000   0.000000
# 25%    -0.440400   0.000000   0.864250   0.000000
# 50%     0.000000   0.057000   0.896000   0.000000
# 75%     0.278900   0.105000   0.955750   0.091000
# max     0.840200   0.116000   1.000000   0.273000

# %%
# Describing the carnival Sentiment
ccl_df.describe()
# Out:
#         Compound   Negative    Neutral   Positive
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.086115   0.025300   0.924800   0.049900
# std     0.368151   0.055935   0.088671   0.073388
# min    -0.822500   0.000000   0.696000   0.000000
# 25%    -0.019300   0.000000   0.926000   0.000000
# 50%     0.000000   0.000000   0.934000   0.016500
# 75%     0.273200   0.012250   1.000000   0.071000
# max     0.902200   0.227000   1.000000   0.304000

# %%
# Describing the delta Sentiment
dal_df.describe()
# Out:
#         Compound   Negative    Neutral   Positive
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.133795   0.042250   0.880900   0.076950
# std     0.405374   0.052465   0.102987   0.084543
# min    -0.670500   0.000000   0.706000   0.000000
# 25%    -0.038275   0.000000   0.817000   0.000000
# 50%     0.000000   0.018000   0.862500   0.059000
# 75%     0.506000   0.088500   1.000000   0.128000
# max     0.836000   0.174000   1.000000   0.276000

# %%
# Describing the ESTY Sentiment
esty_df.describe()
# Out:
#        Compound  Negative   Neutral  Positive
# count  3.000000       3.0  3.000000  3.000000
# mean   0.460933       0.0  0.889000  0.111000
# std    0.404681       0.0  0.098504  0.098504
# min    0.000000       0.0  0.812000  0.000000
# 25%    0.312450       0.0  0.833500  0.072500
# 50%    0.624900       0.0  0.855000  0.145000
# 75%    0.691400       0.0  0.927500  0.166500
# max    0.757900       0.0  1.000000  0.188000

# %%
# Describing the SP500 Sentiment
sp500_df.describe()
# Out:
#         Compound   Negative    Neutral   Positive
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.441420   0.013200   0.874700   0.112100
# std     0.360332   0.033549   0.081269   0.080123
# min    -0.542300   0.000000   0.750000   0.000000
# 25%     0.238700   0.000000   0.793250   0.072500
# 50%     0.509950   0.000000   0.904000   0.096000
# 75%     0.699000   0.000000   0.918000   0.157500
# max     0.855500   0.115000   1.000000   0.250000

# %% [markdown]
# # Tokenizer
#
# 1. Lowercase each word
# 2. Removing punctuation
# 3. Removing stopwords

# %%
import re
from string import punctuation
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import WordNetLemmatizer, PorterStemmer

# %%
# Instantiating the lemmatizer
lemmatizer = WordNetLemmatizer()

# %%
# Completing the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    # Expanding the default stopwords list if necessary
    sw = stopwords.words("english")
    sw.append("seen")
    sw.append("california")
    sw.append("file")
    sw.append("houston")
    sw.append("chars")
    sw.append("staff")
    sw.append("photo")
    sw.append("since")
    sw.append("taken")
    sw.append("illustration")
    sw.append("li")
    
    # cleaning text   
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub(' ', text)
    # Removing the punctuation
    words = word_tokenize(re_clean)
    # Converting the words to lowercase
    words = [word.lower() for word in words]
    # Removing the stop words
    words = [word for word in words if word not in sw]
    # Lemmatizing Words into root words
    tokens = [lemmatizer.lemmatize(word) for word in words]
    
    return tokens

# %%
# Creating a new tokens column for lb
lb_df["tokens"] = lb_df["text"].apply(tokenizer)
lb_df.head(5)
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.0000     0.000    1.000     0.000
# 1    0.0000     0.000    1.000     0.000
# 2    0.4588     0.088    0.722     0.191
# 3    0.0000     0.000    1.000     0.000
# 4   -0.4404     0.108    0.892     0.000
#
#                                                 text  \
# 0  Gap Inc.s \r\n GPS,\r\n -0.84%\r\nAthleta bran...
# 1  Beyond Meat Inc. \r\n BYND,\r\n +5.39%\r\nwas ...
# 2  "If the public sector will not take 'personal ...
# 3  For Immediate Release\r\nChicago, IL – Decembe...
# 4  Image source: The Motley Fool.\r\nConagra Bran...
#
#                                               tokens
# 0  [gap, inc, gps, athleta, brand, expanded, size...
# 1  [beyond, meat, inc, bynd, downgraded, neutral,...
# 2  [public, sector, take, personal, responsibilit...
# 3  [immediate, release, chicago, il, december, za...
# 4  [image, source, motley, fool, conagra, brand, ...

# %%
# Creating a new tokens column for ccl
ccl_df["tokens"] = ccl_df["text"].apply(tokenizer)
ccl_df.head(5)
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.0000     0.000    1.000     0.000
# 1   -0.3182     0.067    0.933     0.000
# 2   -0.3182     0.065    0.935     0.000
# 3   -0.0772     0.098    0.784     0.118
# 4   -0.8225     0.227    0.740     0.033
#
#                                                 text  \
# 0  By Tim McDonaldBusiness reporter, BBC News\r\n...
# 1  By Reuters Staff\r\nJan 11 (Reuters) - Carniva...
# 2  By Reuters Staff\r\n(Adds detail on cash burn ...
# 3  Bad news for any eager cruisegoers: cruise lin...
# 4  The coronavirus pandemic crisis shows no signs...
#
#                                               tokens
# 0  [tim, mcdonaldbusiness, reporter, bbc, news, i...
# 1  [reuters, jan, reuters, carnival, corp, report...
# 2  [reuters, add, detail, cash, burn, rate, jan, ...
# 3  [bad, news, eager, cruisegoers, cruise, line, ...
# 4  [coronavirus, pandemic, crisis, show, sign, ab...

# %%
# Creating a new tokens column for dal
dal_df["tokens"] = dal_df["text"].apply(tokenizer)
dal_df.head(5)
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.5719     0.090    0.706     0.204
# 1    0.5719     0.088    0.713     0.200
# 2   -0.1531     0.048    0.952     0.000
# 3    0.3182     0.053    0.859     0.089
# 4    0.0000     0.000    1.000     0.000
#
#                                                 text  \
# 0  CHICAGO (Reuters) - United Airlines and Delta ...
# 1  CHICAGO (Reuters) -United Airlines and Delta A...
# 2  An airplane takes off from the Ronald Reagan N...
# 3  Vulnerable seniors and those who care for them...
# 4  By Reuters Staff\r\nFILE PHOTO: Delta Air Line...
#
#                                               tokens
# 0  [chicago, reuters, united, airline, delta, air...
# 1  [chicago, reuters, united, airline, delta, air...
# 2  [airplane, take, ronald, reagan, national, air...
# 3  [vulnerable, senior, care, remain, top, priori...
# 4  [reuters, delta, air, line, passenger, plane, ...

# %%
# Creating a new tokens column for esty
esty_df["tokens"] = esty_df["text"].apply(tokenizer)
esty_df.head(5)
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.0000       0.0    1.000     0.000
# 1    0.7579       0.0    0.812     0.188
# 2    0.6249       0.0    0.855     0.145
#
#                                                 text  \
# 0  Cheryl Camarato and Susan Wybiral have owned t...
# 1  Here are five destinations perfect for all lev...
# 2  The New York theater industry supports more th...
#
#                                               tokens
# 0  [cheryl, camarato, susan, wybiral, owned, minu...
# 1  [five, destination, perfect, level, experience...
# 2  [new, york, theater, industry, support, local,...

# %%
# Creating a new tokens column for sp500
sp500_df["tokens"] = sp500_df["text"].apply(tokenizer)
sp500_df.head(5)
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.2584     0.000    0.938     0.062
# 1    0.5908     0.000    0.853     0.147
# 2    0.0000     0.000    1.000     0.000
# 3    0.0000     0.000    1.000     0.000
# 4   -0.5423     0.091    0.909     0.000
#
#                                                 text  \
# 0  By Reuters Staff\r\nLONDON, Jan 7 (Reuters) - ...
# 1  LONDON (Reuters) - Rioters storming the U.S. C...
# 2  BRAZIL - 2020/11/18: In this photo illustratio...
# 3  GLóRIA DE DOURADOS, BRAZIL - 2020/06/02: In th...
# 4  The year 2020 was off to a bad start as the co...
#
#                                               tokens
# 0  [reuters, london, jan, reuters, look, day, ahe...
# 1  [london, reuters, rioter, storming, u, capitol...
# 2  [brazil, hexcel, corporation, logo, displayed,...
# 3  [gl, ria, de, dourados, brazil, dish, network,...
# 4  [year, bad, start, coronavirus, began, spreadi...

# %% [markdown]
# # NGrams and Frequency Analysis
#
# Look at the ngrams and word frequency for each ticker symbol
#
# 1. Set n-grams to N=2 using NLTK
# 2. List the top 20 words for each ticker

# %%
from nltk import ngrams
from collections import Counter

# %%
# Generating the lb N-grams where N=2!
lb_text = lb_df["text"].str.cat()
clean_lb_text =  tokenizer(lb_text)
bigram_counts = Counter(ngrams(clean_lb_text, n=2))
bigram_counts.most_common(20)
# Out:
# [(('image', 'source'), 7),
#  (('source', 'motley'), 7),
#  (('motley', 'fool'), 7),
#  (('q', 'earnings'), 7),
#  (('earnings', 'calljan'), 7),
#  (('calljan', 'et'), 7),
#  (('et', 'content'), 7),
#  (('content', 'ul'), 7),
#  (('ul', 'prepared'), 7),
#  (('prepared', 'remark'), 7),
#  (('remark', 'question'), 7),
#  (('question', 'answer'), 7),
#  (('answer', 'call'), 6),
#  (('inc', 'nyse'), 3),
#  (('immediate', 'release'), 2),
#  (('release', 'chicago'), 2),
#  (('chicago', 'il'), 2),
#  (('il', 'december'), 2),
#  (('december', 'zacks'), 2),
#  (('zacks', 'com'), 2)]

# %%
# Generating the ccl N-grams where N=2!
ccl_text = ccl_df["text"].str.cat()
clean_ccl_text =  tokenizer(ccl_text)
bigram_counts = Counter(ngrams(clean_ccl_text, n=2))
bigram_counts.most_common(20)
# Out:
# [(('wall', 'street'), 6),
#  (('new', 'york'), 4),
#  (('reuters', 'year'), 4),
#  (('year', 'wild'), 4),
#  (('wild', 'one'), 4),
#  (('one', 'wall'), 4),
#  (('street', 'bookended'), 4),
#  (('bookended', 'end'), 4),
#  (('end', 'longest'), 4),
#  (('longest', 'bull'), 4),
#  (('bull', 'market'), 4),
#  (('market', 'history'), 4),
#  (('history', 'battering'), 4),
#  (('battering', 'equity'), 4),
#  (('reuters', 'live'), 4),
#  (('live', 'blog'), 4),
#  (('blog', 'u'), 4),
#  (('u', 'uk'), 4),
#  (('uk', 'european'), 4),
#  (('european', 'stock'), 4)]

# %%
# Generating the dal N-grams where N=2!
dal_text = dal_df["text"].str.cat()
clean_dal_text =  tokenizer(dal_text)
bigram_counts = Counter(ngrams(clean_dal_text, n=2))
bigram_counts.most_common(20)
# Out:
# [(('delta', 'air'), 5),
#  (('air', 'line'), 5),
#  (('coronavirus', 'disease'), 5),
#  (('disease', 'covid'), 5),
#  (('united', 'kingdom'), 4),
#  (('negative', 'covid'), 4),
#  (('within', 'hour'), 4),
#  (('reuters', 'delta'), 4),
#  (('amid', 'concern'), 4),
#  (('united', 'state'), 3),
#  (('b', 'c'), 3),
#  (('washington', 'reuters'), 3),
#  (('reuters', 'u'), 3),
#  (('chicago', 'reuters'), 2),
#  (('reuters', 'united'), 2),
#  (('united', 'airline'), 2),
#  (('airline', 'delta'), 2),
#  (('line', 'requiring'), 2),
#  (('requiring', 'passenger'), 2),
#  (('passenger', 'flight'), 2)]

# %%
# Generating the esty N-grams where N=2!
esty_text = esty_df["text"].str.cat()
clean_esty_text =  tokenizer(esty_text)
bigram_counts = Counter(ngrams(clean_esty_text, n=2))
bigram_counts.most_common(20)
# Out:
# [(('cheryl', 'camarato'), 1),
#  (('camarato', 'susan'), 1),
#  (('susan', 'wybiral'), 1),
#  (('wybiral', 'owned'), 1),
#  (('owned', 'minuteman'), 1),
#  (('minuteman', 'press'), 1),
#  (('press', 'printing'), 1),
#  (('printing', 'franchise'), 1),
#  (('franchise', 'fairfield'), 1),
#  (('fairfield', 'ct'), 1),
#  (('ct', 'nearly'), 1),
#  (('nearly', 'ten'), 1),
#  (('ten', 'year'), 1),
#  (('year', 'essential'), 1),
#  (('essential', 'business'), 1),
#  (('business', 'let'), 1),
#  (('let', 'covid'), 1),
#  (('covid', 'slow'), 1),
#  (('slow', 'fair'), 1),
#  (('fair', 'five'), 1)]

# %%
# Generating the sp500 N-grams where N=2!
sp500_text = sp500_df["text"].str.cat()
clean_sp500_text =  tokenizer(sp500_text)
bigram_counts = Counter(ngrams(clean_sp500_text, n=2))
bigram_counts.most_common(20)
# Out:
# [(('economic', 'recovery'), 3),
#  (('rioter', 'storming'), 2),
#  (('storming', 'u'), 2),
#  (('u', 'capitol'), 2),
#  (('capitol', 'havent'), 2),
#  (('havent', 'distracted'), 2),
#  (('distracted', 'trader'), 2),
#  (('trader', 'focusing'), 2),
#  (('focusing', 'implication'), 2),
#  (('implication', 'democrat'), 2),
#  (('corporation', 'logo'), 2),
#  (('logo', 'displayed'), 2),
#  (('displayed', 'smartphone'), 2),
#  (('smartphone', 'rafael'), 2),
#  (('rafael', 'henrique'), 2),
#  (('henrique', 'sopa'), 2),
#  (('sopa', 'image'), 2),
#  (('amp', 'p'), 2),
#  (('get', 'full'), 2),
#  (('walter', 'schloss'), 2)]

# %%
# Using the token_count function to generate the top 20 words
def token_count(tokens, N=20):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Getting the top 20 words for lb
token_count(clean_lb_text, N=20)
# Out:
# [('image', 7),
#  ('source', 7),
#  ('motley', 7),
#  ('fool', 7),
#  ('q', 7),
#  ('earnings', 7),
#  ('calljan', 7),
#  ('et', 7),
#  ('content', 7),
#  ('ul', 7),
#  ('prepared', 7),
#  ('remark', 7),
#  ('question', 7),
#  ('answer', 7),
#  ('company', 6),
#  ('call', 6),
#  ('inc', 5),
#  ('analyst', 5),
#  ('nyse', 5),
#  ('brand', 4)]

# %%
# Getting the top 20 words for ccl
token_count(clean_ccl_text, N=20)
# Out:
# [('reuters', 20),
#  ('live', 12),
#  ('market', 11),
#  ('covid', 7),
#  ('u', 7),
#  ('european', 7),
#  ('news', 6),
#  ('year', 6),
#  ('wall', 6),
#  ('street', 6),
#  ('cruise', 5),
#  ('stock', 5),
#  ('rise', 5),
#  ('sea', 4),
#  ('state', 4),
#  ('recovery', 4),
#  ('co', 4),
#  ('new', 4),
#  ('york', 4),
#  ('wild', 4)]

# %%
# Getting the top 20 words for dal
token_count(clean_dal_text, N=20)
# Out:
# [('reuters', 14),
#  ('covid', 14),
#  ('united', 9),
#  ('airline', 8),
#  ('passenger', 8),
#  ('delta', 7),
#  ('air', 7),
#  ('coronavirus', 7),
#  ('washington', 6),
#  ('line', 5),
#  ('airport', 5),
#  ('disease', 5),
#  ('u', 5),
#  ('kingdom', 4),
#  ('negative', 4),
#  ('test', 4),
#  ('within', 4),
#  ('hour', 4),
#  ('c', 4),
#  ('amid', 4)]

# %%
# Getting the top 20 words for esty
token_count(clean_esty_text, N=20)
# Out:
# [('cowassock', 2),
#  ('new', 2),
#  ('theater', 2),
#  ('cheryl', 1),
#  ('camarato', 1),
#  ('susan', 1),
#  ('wybiral', 1),
#  ('owned', 1),
#  ('minuteman', 1),
#  ('press', 1),
#  ('printing', 1),
#  ('franchise', 1),
#  ('fairfield', 1),
#  ('ct', 1),
#  ('nearly', 1),
#  ('ten', 1),
#  ('year', 1),
#  ('essential', 1),
#  ('business', 1),
#  ('let', 1)]

# %%
# Getting the top 20 words for sp500
token_count(clean_sp500_text, N=20)
# Out:
# [('day', 8),
#  ('u', 8),
#  ('market', 8),
#  ('stock', 6),
#  ('democrat', 4),
#  ('start', 4),
#  ('recovery', 4),
#  ('get', 4),
#  ('series', 4),
#  ('pdf', 4),
#  ('gt', 4),
#  ('reuters', 3),
#  ('capitol', 3),
#  ('image', 3),
#  ('first', 3),
#  ('economic', 3),
#  ('equity', 3),
#  ('may', 3),
#  ('show', 3),
#  ('board', 3)]

# %% [markdown]
# # Word Clouds

# %%
import numpy as np
from PIL import Image
import matplotlib as mpl
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generating the lb word cloud
big_string = '. '.join(clean_lb_text)
wc = WordCloud().generate(big_string)
plt.title("L Brands Word Cloud", fontsize=40, loc="center", fontweight="bold")
plt.imshow(wc)

# %%
# Generating the ccl word cloud
big_string = '. '.join(clean_ccl_text)
wc = WordCloud().generate(big_string)
plt.title("Carnival Cruise Word Cloud", fontsize=40, loc="center", fontweight="bold")
plt.imshow(wc)

# %%
# Generating the dal word cloud
big_string = '. '.join(clean_dal_text)
wc = WordCloud().generate(big_string)
plt.title("Delta Airlines Word Cloud", fontsize=40, loc="center", fontweight="bold")
plt.imshow(wc)

# %%
# Generating the esty word cloud
big_string = '. '.join(clean_esty_text)
wc = WordCloud().generate(big_string)
plt.title("ESTY Word Cloud", fontsize=40, loc="center", fontweight="bold")
plt.imshow(wc)

# %%
# Generating the SP500 word cloud
big_string = '. '.join(clean_sp500_text)
wc = WordCloud().generate(big_string)
plt.title("S&P500 Word Cloud", fontsize=40, loc="center", fontweight="bold")
plt.imshow(wc)
